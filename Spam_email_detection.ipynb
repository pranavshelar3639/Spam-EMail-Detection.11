# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavshelar3639/Spam-EMail-Detection.11/blob/main/Spam_email_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#loading the data from csv file tp a pandas dataframe
raw_mail_data = pd.read_csv('mail_data.csv')

# %%
# replace the null values with a null string
mail_data = raw_mail_data.where((pd.notnull(raw_mail_data)),'')

# %%
#printing the first 5 rows of the dataframe
mail_data.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
#checking the number of rows and columbs in the dataframe
mail_data.shape
# Out:
# (5572, 2)

# %% [markdown]
# label **encoding**

# %%
#label spam mail as 0; ham mail as 1;
mail_data.loc[mail_data['Category'] =='spam', 'Category',] = 0
mail_data.loc[mail_data['Category'] == 'ham',  'Category,'] = 1

# %%
from re import X
# separating the data as texts and label

X = mail_data['Message']
Y = mail_data['Category']

# %%
print(X)
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                 Will ü b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: Message, Length: 5572, dtype: object

# %%
print(Y)
# Out:
# 0       ham
# 1       ham
# 2         0
# 3       ham
# 4       ham
#        ...
# 5567      0
# 5568    ham
# 5569    ham
# 5570    ham
# 5571    ham
# Name: Category, Length: 5572, dtype: object

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=3)

# %%
print(X.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (5572,)
# (4457,)
# (1115,)

# %% [markdown]
# feature extraction

# %%
# transform the text data to feature vector that can be used as input to the logistic regression
feature_extraction = TfidfVectorizer(min_df = 1, stop_words='english', lowercase=True)

X_train_features = feature_extraction.fit_transform(X_train)
X_test_features = feature_extraction.transform(X_test)


# convert Y_ train and Y_test values as integers
# The 'ham' string needs to be converted to integer 1 before astype('int')
Y_train = Y_train.replace('ham', 1).astype('int')
Y_test = Y_test.replace('ham', 1).astype('int')
# Out:
# /tmp/ipython-input-3776434327.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Y_train = Y_train.replace('ham', 1).astype('int')
# /tmp/ipython-input-3776434327.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Y_test = Y_test.replace('ham', 1).astype('int')

# %%
print(X_train)
# Out:
# 3075                  Don know. I did't msg him recently.
# 1787    Do you know why god created gap between your f...
# 1614                         Thnx dude. u guys out 2nite?
# 4304                                      Yup i'm free...
# 3266    44 7732584351, Do you want a New Nokia 3510i c...
#                               ...
# 789     5 Free Top Polyphonic Tones call 087018728737,...
# 968     What do u want when i come back?.a beautiful n...
# 1667    Guess who spent all last night phasing in and ...
# 3321    Eh sorry leh... I din c ur msg. Not sad alread...
# 1688    Free Top ringtone -sub to weekly ringtone-get ...
# Name: Message, Length: 4457, dtype: object

# %%
print(X_train_features)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 34775 stored elements and shape (4457, 7431)>
#   Coords	Values
#   (0, 2329)	0.38783870336935383
#   (0, 3811)	0.34780165336891333
#   (0, 2224)	0.413103377943378
#   (0, 4456)	0.4168658090846482
#   (0, 5413)	0.6198254967574347
#   (1, 3811)	0.17419952275504033
#   (1, 3046)	0.2503712792613518
#   (1, 1991)	0.33036995955537024
#   (1, 2956)	0.33036995955537024
#   (1, 2758)	0.3226407885943799
#   (1, 1839)	0.2784903590561455
#   (1, 918)	0.22871581159877646
#   (1, 2746)	0.3398297002864083
#   (1, 2957)	0.3398297002864083
#   (1, 3325)	0.31610586766078863
#   (1, 3185)	0.29694482957694585
#   (1, 4080)	0.18880584110891163
#   (2, 6601)	0.6056811524587518
#   (2, 2404)	0.45287711070606745
#   (2, 3156)	0.4107239318312698
#   (2, 407)	0.509272536051008
#   (3, 7414)	0.8100020912469564
#   (3, 2870)	0.5864269879324768
#   (4, 2870)	0.41872147309323743
#   (4, 487)	0.2899118421746198
#   :	:
# ...

# %% [markdown]
# T**RAINING THE MODEL**

# %% [markdown]
# LOGISTIC REGRESSSION

# %%
model = LogisticRegression()

# %%
#training the logistic Regression model with the training data
model.fit(X_train_features, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# evaluating the trainig model

# %%
#predictoin on training data
prediction_on_training_data = model.predict(X_train_features)
accuracy_on_training_data = accuracy_score(Y_train, prediction_on_training_data)

# %%
print('Accuracacy on trainig data :', accuracy_on_training_data)
# Out:
# Accuracacy on trainig data : 0.9676912721561588

# %%
#prediction on test data
prediction_on_test_data = model.predict (X_test_features)
accuracy_on_test_data = accuracy_score(Y_test, prediction_on_test_data)

# %%
print('Accuracy on test data :' , accuracy_on_test_data)
# Out:
# Accuracy on test data : 0.9668161434977578

# %% [markdown]
# building a predictive systen

# %%
input_mail = ["Nah I don't think he goes to usf, he lives around here though"]

#convert text to feature vectors

input_data_features = feature_extraction.transform(input_mail)

#making prediction

prediction = model.predict(input_data_features)
print(prediction)

if (prediction[0]==1):
  print('Ham mail')
else:
  print('Spam mail')
# Out:
# [1]
# Ham mail
